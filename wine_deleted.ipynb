# %% [markdown]
# <a href="https://colab.research.google.com/github/Anitagg1/Blueberry-Winery-Project/blob/main/wine_deleted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Wines deleted

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red_wine = pd.read_csv("red_wine.csv")

# %%
white_wine = pd.read_csv('white_wine.csv')

# %%
wines = pd.read_csv('wines.csv')

# %%
red_wine['quality'].hist()

# %%
red_wine['total sulfur dioxide'].hist(bins = 100)

# %%
# comparing same data, less granular
red_wine['total sulfur dioxide'].hist(bins = 10)

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
wines.groupby("wine_type").mean('fixed acidity')
# Out:
#             Unnamed: 0  fixed acidity  ...    alcohol   quality
# wine_type                              ...
# red        3157.945591       8.319637  ...  10.422983  5.636023
# white      3277.399143       6.854788  ...  10.514267  5.877909
#
# [2 rows x 13 columns]

# %%
ax = plt.gca()

red_wine.plot(kind='line',x='quality_label',y='fixed acidity',ax=ax)
red_wine.plot(kind='line',x='quality_label',y='total sulfur dioxide', color='red', ax=ax)

plt.show()

# %%
np.random.seed(1234)
new = red_wine = pd.DataFrame(np.random.randn(10,4),
                  columns=['fixed acidity', 'residual sugar', 'total sulfur dioxide', 'chlorides'])
boxplot = red_wine.boxplot(column=['fixed acidity', 'residual sugar', 'total sulfur dioxide', 'chlorides'])

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         10 non-null     float64
#  1   residual sugar        10 non-null     float64
#  2   total sulfur dioxide  10 non-null     float64
#  3   chlorides             10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 6))
ax[0].boxplot( wines[wines['wine_type'] == 'red']['chlorides'], );
ax[1].boxplot( wines[wines['wine_type'] == 'white']['chlorides']);

# %%
plt.scatter(red_wine.quality_label, red_wine.chlorides)

# %%
boxplot = red_wine.boxplot(column=['fixed acidity', 'residual sugar'], by='quality_label', layout=(2, 1))
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
red_wine[['fixed acidity', 'wine_type', 'quality_label']].boxplot(by=['quality_label'])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
red_wine[['chlorides', 'wine_type', 'quality_label']].boxplot(by=['quality_label'])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
sns.catplot(x='quality_label', y='alcohol', data=red_wine)

# %%
g = sns.catplot(x="quality_label", y="alcohol", hue='quality_label', data=red_wine, kind="violin")

# %%
# combination TSD - alcohol results high, check only high wines
red_wine[(red_wine["total sulfur dioxide"].between(79.363116,300, inclusive=False)) & (red_wine
["alcohol"].between(11.488651,15, inclusive=False)) & (red_wine["quality_label"]=="high")]
# Out:
#       Unnamed: 0  fixed acidity  ...  wine_type  quality_label
# 390          390            5.6  ...        red           high
# 1269        1269            5.5  ...        red           high
#
# [2 rows x 15 columns]

# %%
red_wine[(red_wine["total sulfur dioxide"].between(79.363116,300, inclusive=False)) & (red_wine["alcohol"].between(11.488651,15, inclusive=False)) & (red_wine["quality_label"]=="medium")]
# Out:
#       Unnamed: 0  fixed acidity  ...  wine_type  quality_label
# 95            95            4.7  ...        red         medium
# 198          198            5.4  ...        red         medium
# 230          230            5.2  ...        red         medium
# 338          338           12.4  ...        red         medium
# 354          354            6.1  ...        red         medium
# 493          493            8.7  ...        red         medium
# 494          494            6.5  ...        red         medium
# 499          499            8.7  ...        red         medium
# 591          591            6.6  ...        red         medium
# 802          802            5.1  ...        red         medium
# 836          836            6.7  ...        red         medium
# 837          837            6.7  ...        red         medium
# 861          861            5.8  ...        red         medium
# 1017        1017            8.0  ...        red         medium
# ...

# %%
red_wine[(red_wine["total sulfur dioxide"].between(79.363116,300, inclusive=False)) & (red_wine["alcohol"].between(11.488651,15, inclusive=False)) & (red_wine["quality_label"]=="low")]
# Out:
#       Unnamed: 0  fixed acidity  ...  wine_type  quality_label
# 131          131            5.6  ...        red            low
# 132          132            5.6  ...        red            low
# 553          553            5.0  ...        red            low
# 1235        1235            6.0  ...        red            low
#
# [4 rows x 15 columns]

# %%
#highest quality according to total sulfur dioxide and alcohol, from mean + std to max
red_wine[(red_wine["total sulfur dioxide"].between(79.363116,300, inclusive=False)) & (red_wine["alcohol"].between(11.488651,15, inclusive=False))]
# Out:
#       Unnamed: 0  fixed acidity  ...  wine_type  quality_label
# 95            95            4.7  ...        red         medium
# 131          131            5.6  ...        red            low
# 132          132            5.6  ...        red            low
# 198          198            5.4  ...        red         medium
# 230          230            5.2  ...        red         medium
# 338          338           12.4  ...        red         medium
# 354          354            6.1  ...        red         medium
# 390          390            5.6  ...        red           high
# 493          493            8.7  ...        red         medium
# 494          494            6.5  ...        red         medium
# 499          499            8.7  ...        red         medium
# 553          553            5.0  ...        red            low
# 591          591            6.6  ...        red         medium
# 802          802            5.1  ...        red         medium
# ...

# %%
red_wine[(red_wine["volatile acidity"].between(0.70688,1.59, inclusive=False)) & (red_wine["alcohol"].between(12,14, inclusive=False)) & (red_wine["sulphates"].between(0.75,1.1, inclusive=False))]
# Out:
#      Unnamed: 0  fixed acidity  ...  wine_type  quality_label
# 198         198            5.4  ...        red         medium
# 346         346            6.6  ...        red         medium
# 390         390            5.6  ...        red           high
#
# [3 rows x 15 columns]

# %%
red_wine[(red_wine["volatile acidity"].between(0,0.29906, inclusive=False)) & (red_wine["quality_label"]=="low")]
# Out:
#       Unnamed: 0  fixed acidity  ...  wine_type  quality_label
# 47            47            8.7  ...        red            low
# 291          291           11.0  ...        red            low
# 454          454            7.0  ...        red            low
# 462          462           11.0  ...        red            low
# 465          465           10.0  ...        red            low
# 476          476            9.3  ...        red            low
# 480          480           10.6  ...        red            low
# 572          572           10.2  ...        red            low
# 610          610            8.8  ...        red            low
# 631          631           10.4  ...        red            low
# 679          679           10.8  ...        red            low
# 955          955            8.5  ...        red            low
# 1131        1131            5.9  ...        red            low
# 1233        1233           10.2  ...        red            low
# ...

# %%
g = sns.regplot(x=red_wine['alcohol'], y=red_wine['volatile acidity'], data= red_wine.quality_label)
